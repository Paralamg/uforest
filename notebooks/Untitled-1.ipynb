# %%
# !mim train mmdet ../configs/convnextv2_maskrcnn_tree.py --work-dir ../models/convnextv2_maskrcnn_tree
# Out:
# Training command is /home/paralamg/miniconda3/envs/mmdet/bin/python3.10 /home/paralamg/miniconda3/envs/mmdet/lib/python3.10/site-packages/mmdet/.mim/tools/train.py ../configs/convnextv2_maskrcnn_tree.py --launcher none --work-dir ../models/convnextv2_maskrcnn_tree.
# 05/24 11:20:21 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.16 (main, Dec 11 2024, 16:24:50) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1115174595
#     GPU 0: NVIDIA GeForce GTX 1050 Ti
#     CUDA_HOME: /usr
#     NVCC: Cuda compilation tools, release 12.0, V12.0.140
#     GCC: gcc (Ubuntu 13.3.0-6ubuntu2~24.04) 13.3.0
#     PyTorch: 2.7.0+cu126
#     PyTorch compiling details: PyTorch built with:
#   - GCC 11.2
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2024.2-Product Build 20240605 for Intel(R) 64 architecture applications
# ...
